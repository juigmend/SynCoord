# %% [markdown]
# <center>
#
# *******************************************************************************************
#
# ### Download Video
#
# ##### 1 May 2025
#
# ##### Juan Ignacio Mendoza Garay
#
# *******************************************************************************************
#
# </center>
#
# ##### INFORMATION:
#
# * Downloads video from Youtube and writes a file with properties 'ID' (identification label) and 'fps' (frames per second).
# >
# * Tested with:
#
#     * Python 3.11
#     * Windows 11
# >
# * Dependencies:
#
#     * [Video downloader](https://github.com/yt-dlp/yt-dlp): use the latest version, otherwise it might not work properly.
#         * PIP: https://pypi.org/project/yt-dlp/
#         * Conda: https://anaconda.org/conda-forge/yt-dlp
#     * Other packages might be prompted for installation.
# >
# * Instructions:
#
#     Edit the values indicated with an arrow like this: <---
#
# *******************************************************************************************

# %%
from sys import path as sys_path
from os import chdir as os_chdir

sys_path.append(r"..\src")
import syncoord as sc

os_chdir(r"..\data")

# %% [markdown]
# ***
# ### Set paths and parameters

# %%
project_path = r"string_quartet_Ecossaise" # <--- project folder
vout_path = project_path + r"\input_video" # <--- folder to save video

YT_video_ID = 'cQcukN4BWkM' # <--- this string is at the end of the video's Youtube page URL.
                            #      The Youtube ID follows this string in the URL:
                            #                                            "www.youtube.com/watch?v="

# %% [markdown]
# ***
# ### Get video
# >
# #### Preview and information

# %%
sc.video.download( YT_video_ID, 'info preview')
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=cQcukN4BWkM
# [youtube] cQcukN4BWkM: Downloading webpage
# [youtube] cQcukN4BWkM: Downloading tv client config
# [youtube] cQcukN4BWkM: Downloading player 73381ccc
# [youtube] cQcukN4BWkM: Downloading tv player API JSON
# [youtube] cQcukN4BWkM: Downloading ios player API JSON
# [youtube] cQcukN4BWkM: Downloading m3u8 information
# [info] Available formats for cQcukN4BWkM:
# ID  EXT   RESOLUTION FPS |   FILESIZE   TBR PROTO | VCODEC          VBR ACODEC     MORE INFO
# ------------------------------------------------------------------------------------------------
# sb2 mhtml 48x27        2 |                  mhtml | images                         storyboard
# sb1 mhtml 80x45        1 |                  mhtml | images                         storyboard
# sb0 mhtml 160x90       1 |                  mhtml | images                         storyboard
# ...

# %% [markdown]
# ***
# #### Download and write properties

# %%
sc.video.download( YT_video_ID, 'download',
                   video_folder=vout_path, prop_folder=project_path )
